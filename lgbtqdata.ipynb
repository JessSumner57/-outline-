# %%
## LGBTQ Data

# %%
import numpy as np
import pandas as pd

# %%
lgbtq_p = pd.read_excel('lgbtqdata.xlsx', usecols = [0, 1, 10, 11 , 12, 13, 14, 15, 16, 17],
                       header = 1, skiprows = ([i for i in range(1, 4)] + [j for j in range(5, 282)] + [k for k in range (314, 336)]))

# %%
lgbtq_p.head(5)
# Out:
#    Area code             Area name  Straight or Heterosexual\n(percent)  \
# 0  E09000002  Barking and Dagenham                                88.58
# 1  E09000003                Barnet                                87.27
# 2  E09000004                Bexley                                90.92
# 3  E09000005                 Brent                                85.10
# 4  E09000006               Bromley                                89.98
#
#    Gay or Lesbian\n(percent)  Bisexual\n(percent)  Pansexual\n(percent)  \
# 0                       0.82                 0.97                  0.38
# 1                       1.25                 1.06                  0.36
# 2                       1.05                 0.81                  0.18
# 3                       1.31                 1.29                  0.45
# 4                       1.53                 0.95                  0.16
#
#    Asexual\n(percent)  Queer\n(percent)  \
# 0                0.03              0.01
# 1                0.05              0.03
# 2                0.03              0.02
# 3                0.04              0.03
# 4                0.05              0.03
#
#    All other sexual orientations\n(percent)  Not answered\n(percent)
# 0                                      0.07                     9.14
# 1                                      0.04                     9.94
# 2                                      0.02                     6.97
# 3                                      0.07                    11.70
# 4                                      0.02                     7.30

# %%
lgbtq_p.tail(5)
# Out:
#     Area code       Area name  Straight or Heterosexual\n(percent)  \
# 27  E09000029          Sutton                                89.95
# 28  E09000030   Tower Hamlets                                83.07
# 29  E09000031  Waltham Forest                                85.99
# 30  E09000032      Wandsworth                                86.47
# 31  E09000033     Westminster                                83.31
#
#     Gay or Lesbian\n(percent)  Bisexual\n(percent)  Pansexual\n(percent)  \
# 27                       1.17                 0.97                  0.19
# 28                       3.96                 2.52                  0.46
# 29                       2.26                 1.62                  0.44
# 30                       3.05                 1.74                  0.26
# 31                       3.47                 1.54                  0.33
#
#     Asexual\n(percent)  Queer\n(percent)  \
# 27                0.04              0.01
# 28                0.06              0.13
# 29                0.05              0.09
# 30                0.06              0.05
# 31                0.06              0.05
#
#     All other sexual orientations\n(percent)  Not answered\n(percent)
# 27                                      0.01                     7.65
# 28                                      0.04                     9.76
# 29                                      0.05                     9.49
# 30                                      0.03                     8.34
# 31                                      0.04                    11.20
